# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is **Andre Mahfouz**.
# I am a fresh psychology graduate looking to pursue a master's degree in social research.

# %% [markdown]
# *I'm interested in data science as an extension of social research and social policy. Local and regional governments have access to a wealth of information which they can leverage to make better decisions regarding the wellbeing of their citizens and, with the help of data science, should be able to study and monitor changes in their spheres of influence.*

# %% [markdown]
# ### This is just a simple python code line that prints *Hello World!*

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# #### So I'm somewhat familiar with markdown; I use Joplin to take notes for university/work.
# ---
# You can do a lot in markdown, including:
# - Bulleted lists
# - Numbered lists, as such:
#     1. Uno
#     2. Dos
#     3. Tres
# - Code blocks
# - etc.
#
# ---
#
# #### This is what a code block looks like:
# `print("Hello World!")`
#
# ---
#
# #### You can also create tables in Markdown:
#
# | Title 1 | Title 2 |
# |---------|---------|
# | Entry 1 | Entry 2 |
#
# *P.S.: The table isn't displaying properly from the link for some reason. I'll attach a PDF as well on <a href="https://github.com/andremahfouz/notebooks/blob/main/Jupyter_Notebook_Andre-Mahfouz.ipynb">my github page</a>.*
